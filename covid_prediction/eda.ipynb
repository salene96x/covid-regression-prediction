# %%
# %load_ext autoreload
# %autoreload 2

# %%
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from etl import ETL
import numpy as np

# %%
metadata_path = '/usr/src/covid_prediction/our-world-in-data-covid19-dataset/owid-covid-data.csv'
vac_path = '/usr/src/covid_prediction/covid-vaccination-dataset/vaccinations.csv'
etl = ETL(metadata_path, vac_path)
df = etl.run()

# %%
df
# Out:
#       index  iso_code  continent  total_cases  new_cases  new_cases_smoothed  \
# 0    183133      3166        142          0.0        0.0               0.000
# 1    183134      3166        142          0.0        0.0               0.000
# 2    183135      3166        142          0.0        0.0               0.000
# 3    183136      3166        142          0.0        0.0               0.000
# 4    183137      3166        142          0.0        0.0               0.000
# ..      ...       ...        ...          ...        ...                 ...
# 939  184072      3166        142    4592284.0     2108.0            2098.714
# 940  184073      3166        142    4594127.0     1843.0            2362.000
# 941  184074      3166        142    4596559.0     2432.0            2055.857
# 942  184075      3166        142    4598725.0     2166.0            2093.571
# 943  184076      3166        142    4600978.0     2253.0            2061.143
#
# ...

# %%
plt.figure(figsize=(10,8))
x_data, y_data = (df["new_deaths"].values, df["population"].values,)
plt.plot(x_data, y_data)
plt.ylabel('total_vac')
plt.xlabel('new_deaths')
# Out:
# Text(0.5, 0, 'new_deaths')

# %%
df.shape[0]
# Out:
# 944

# %%
df
# Out:
#       index  iso_code  continent  total_cases  new_cases  new_cases_smoothed  \
# 0    183133      3166        142          0.0        0.0               0.000
# 1    183134      3166        142          0.0        0.0               0.000
# 2    183135      3166        142          0.0        0.0               0.000
# 3    183136      3166        142          0.0        0.0               0.000
# 4    183137      3166        142          0.0        0.0               0.000
# ..      ...       ...        ...          ...        ...                 ...
# 939  184072      3166        142    4592284.0     2108.0            2098.714
# 940  184073      3166        142    4594127.0     1843.0            2362.000
# 941  184074      3166        142    4596559.0     2432.0            2055.857
# 942  184075      3166        142    4598725.0     2166.0            2093.571
# 943  184076      3166        142    4600978.0     2253.0            2061.143
#
# ...

# %%
max(df['total_vaccinations'])
# Out:
# 141814894.0

# %%
df.plot(
    kind='scatter',
    x='total_vaccinations',
    y='new_deaths',
    label='new_deaths vs total_vaccinations(THA)',
    alpha=0.2,
    figsize=(20,15),
    s=df['new_deaths'],
    c='total_vaccinations',
    cmap=plt.get_cmap('jet'),
    colorbar=True)
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='new_deaths'>

# %%
df.plot(
    kind='scatter',
    x='population',
    y='new_deaths',
    label='new_deaths vs population(THA)',
    alpha=0.2,
    figsize=(20,15),
    s=df['new_deaths'],
    c='population',
    cmap=plt.get_cmap('jet'),
    colorbar=True)
# Out:
# <AxesSubplot:xlabel='population', ylabel='new_deaths'>

# %%
df.plot(
    kind='scatter',
    x='total_cases',
    y='new_deaths',
    label='new_deaths vs total_cases(THA)',
    alpha=0.2,
    figsize=(20,15),
    s=df['new_deaths'],
    c='total_cases',
    cmap=plt.get_cmap('jet'),
    colorbar=True)
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='new_deaths'>

# %%
df.plot(
    kind='scatter',
    x='new_cases',
    y='new_deaths',
    label='new_deaths vs new_cases(THA)',
    alpha=0.2,
    figsize=(20,15),
    s=df['new_deaths'],
    c='new_cases',
    cmap=plt.get_cmap('jet'),
    colorbar=True)
# Out:
# <AxesSubplot:xlabel='new_cases', ylabel='new_deaths'>
